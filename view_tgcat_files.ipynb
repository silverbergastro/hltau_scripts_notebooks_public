# %%
from astropy.io import fits
from astropy.table import Table

# %%
testhdu = fits.open('../tgcat_evt_files/tgcid_6016_evt2.gz')
testhdu.info()
# Out:
# Filename: ../tgcat_evt_files/tgcid_6016_evt2.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      30   ()
#   1  EVENTS        1 BinTableHDU   1098   400629R x 26C   [1D, 1J, 1E, 1E, 1I, 1I, 1I, 1I, 1E, 1E, 1E, 1E, 1I, 1J, 1I, 1E, 1I, 1I, 1I, 1I, 1E, 1E, 1I, 1I, 1I, 32X]
#   2  REGION        1 BinTableHDU    265   3R x 9C   [1I, 16A, 1E, 1E, 2E, 1E, 16A, 1I, 1I]
#   3  GTI           7 BinTableHDU     28   2R x 2C   [1D, 1D]
#   4  GTI           5 BinTableHDU     28   1R x 2C   [1D, 1D]
#   5  GTI           6 BinTableHDU     28   2R x 2C   [1D, 1D]
#   6  GTI           8 BinTableHDU     28   5R x 2C   [1D, 1D]

# %%
testhdu[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HDUNAME = 'PRIMARY '
# ORIGIN  = 'ASC     '           / Source of FITS file
# CREATOR = 'tg_resolve_events - CIAO 4.12' / tool that created this output
# CHECKSUM= '3pUh4mSf3mSf3mSf'   / HDU checksum updated 2021-03-30T15:16:39
# DATASUM = '        '           / data unit checksum updated 2021-03-30T15:16:34
# DATE    = '2021-03-30T15:16:39' / Date and time of file creation
# ASCDSVER= 'CIAO 4.12'          / ASCDS version number
# MJD-OBS =  5.8418620406257E+04 / Modified Julian date of observation
# DATE-OBS= '2018-10-27T14:53:23' / Observation start date
# ...

# %%
testhdu[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   58 / width of table in bytes
# NAXIS2  =                    3 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    9 / number of fields in each row
# EXTNAME = 'REGION  '           / name of this binary table extension
# HDUNAME = 'REGION  '           / ASCDM block name
# TTYPE1  = 'SOURCE  '           / Source Number
# TFORM1  = '1I      '           / format of field
# TLMIN1  =                    0
# TTYPE2  = 'SHAPE   '           / Shape of the region
# TFORM2  = '16A     '           / format of field
# TTYPE3  = 'X       '           / Sky coords
# TFORM3  = '1E      '           / format of field
# TUNIT3  = 'pixel   '
# ...

# %%
testtable = Table(testhdu[2].data)
testtable
# Out:
# <Table length=3>
# SOURCE      SHAPE          X        Y             R          ROTANG      GRATING      TG_PART COMPONENT
# int16       str16       float32  float32      float32[2]    float32       str16        int16    int16
# ------ ---------------- -------- -------- ----------------- -------- ---------------- ------- ---------
#      1 circle           4125.023 4093.654  30.016575 .. 0.0      0.0 hetg                   0         1
#      1 rotbox           4125.023 4093.654 8184.7207 .. 75.0 92.05049 hetg                   1         2
#      1 rotbox           4125.023 4093.654 8244.721 .. 100.0 82.09049 hetg                   2         3

# %%
testhdu[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   82 / width of table in bytes
# NAXIS2  =               400629 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   26 / number of fields in each row
# EXTNAME = 'EVENTS  '           / name of this binary table extension
# HDUNAME = 'EVENTS  '           / ASCDM block name
# COMMENT                               +------------------+
# COMMENT                               | AXAF FITS   File |
# COMMENT                               +------------------+
# COMMENT  *********************************************************
# COMMENT  >    This file is written following certain AXAF-ASC    <
# COMMENT  >    conventions which are documented in ASC-FITS-2.0   <
# ...

# %%
testpha = fits.open('../tgcat_evt_files/tgcid_6016_pha2.gz')
testpha.info()
# Out:
# Filename: ../tgcat_evt_files/tgcid_6016_pha2.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()
#   1  SPECTRUM      1 BinTableHDU    260   12R x 13C   [1I, 1I, 1I, 1I, 1E, 1E, 8192I, 8192I, 8192E, 8192I, 8192I, 8192D, 8192D]
#   2  REGION        1 BinTableHDU    139   36R x 11C   [1I, 64A, 16A, 1E, 1E, 2E, 1E, 1I, 1I, 1I, 1I]

# %%
testpha[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  110 / width of table in bytes
# NAXIS2  =                   36 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   11 / number of fields in each row
# EXTNAME = 'REGION  '           / name of this binary table extension
# HDUNAME = 'REGION  '           / ASCDM block name
# ORIGIN  = 'ASC     '           / Source of FITS file
# CREATOR = 'tgextract - Version CIAO 4.12' / tool that created this output
# ASCDSVER= 'CIAO 4.12'          / ASCDS version number
# REVISION=                    2 / Processing version of data
# CHECKSUM= 'CgqOEfoMCfoMCfoM'   / HDU checksum updated 2021-03-30T15:16:56
# ...

# %%
Table(testpha[2].data)
# Out:
# <Table length=36>
# SPEC_NUM                              ROWID                                    SHAPE         TG_LAM  ... TG_PART TG_SRCID  TG_M COMPONENT
#  int16                                str64                                    str16        float32  ...  int16   int16   int16   int16
# -------- ---------------------------------------------------------------- ---------------- --------- ... ------- -------- ----- ---------
#        1 SOURCE                                                           box              3.7466667 ...       1        1    -3         1
#        1 BACKGROUND_UP                                                    box              3.7466667 ...       1        1    -3         2
#        1 BACKGROUND_DOWN                                                  box              3.7466667 ...       1        1    -3         3
#        2 SOURCE                                                           box                   5.62 ...       1        1    -2         4
# ...
